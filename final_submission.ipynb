# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

filepath = "D:\ANYA\project\Complete_Blasting_info (1).csv"

# %%
df = pd.read_csv(filepath)
df
# Out:
#       Unnamed: 0  PM10 (µg/m3)      Time        Date  NO (µg/m3)  \
# 0              0          95.0  00:00:00  2023-02-01   14.484070
# 1              1          95.0  00:15:00  2023-02-01   14.484070
# 2              2          95.0  00:30:00  2023-02-01   15.835914
# 3              3         122.0  00:45:00  2023-02-01   15.914518
# 4              4         122.0  01:00:00  2023-02-01   16.035640
# ...          ...           ...       ...         ...         ...
# 8635        8635          19.0  22:45:00  2023-05-01   17.900000
# 8636        8636          19.0  23:00:00  2023-05-01   17.900000
# 8637        8637          19.0  23:15:00  2023-05-01   19.600000
# 8638        8638          19.0  23:30:00  2023-05-01   20.800000
# 8639        8639          32.0  23:45:00  2023-05-01   21.800000
#
#       PM2.5 (µg/m3)  NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  \
# 0              35.0         90.1       56.2    0.310000    11.986833
# 1              35.0         88.0       55.1    0.330000    11.986833
# 2              35.0         87.7       55.2    0.380000    10.912796
# 3              34.0         88.9       55.7    0.380000    10.613291
# 4              34.0         90.0       55.8    0.380000     7.362361
# ...             ...          ...        ...         ...          ...
# 8635           11.0        100.0       67.8    0.630000    10.000000
# 8636           11.0        100.0       67.7    0.570000    10.000000
# 8637           11.0        100.2       69.2    0.580000     9.900000
# 8638           11.0        100.2       70.2    0.580000     9.500000
# 8639            6.0         98.8       70.3    0.883181    13.054913
#
#       NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# 0            17.7           28.1              0.4
# 1            18.3           27.1              0.4
# 2            19.7           24.9              0.4
# 3            21.3           21.9              0.4
# 4            22.3           16.7              0.4
# ...           ...            ...              ...
# 8635         10.7           26.1              0.1
# 8636         10.4           30.9              0.1
# 8637         10.5           29.6              0.1
# 8638         10.8           30.0              0.1
# 8639         11.0           33.5              0.1
#
# [8640 rows x 13 columns]

# %%
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df.drop(columns=['Date', 'Time'], inplace=True)
df.set_index('DateTime', inplace=True)
df
# Out:
#                      Unnamed: 0  PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00           0          95.0   14.484070           35.0
# 2023-02-01 00:15:00           1          95.0   14.484070           35.0
# 2023-02-01 00:30:00           2          95.0   15.835914           35.0
# 2023-02-01 00:45:00           3         122.0   15.914518           34.0
# 2023-02-01 01:00:00           4         122.0   16.035640           34.0
# ...                         ...           ...         ...            ...
# 2023-05-01 22:45:00        8635          19.0   17.900000           11.0
# 2023-05-01 23:00:00        8636          19.0   17.900000           11.0
# 2023-05-01 23:15:00        8637          19.0   19.600000           11.0
# 2023-05-01 23:30:00        8638          19.0   20.800000           11.0
# 2023-05-01 23:45:00        8639          32.0   21.800000            6.0
#
#                      NO2 (µg/m3)  NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00         90.1       56.2    0.310000    11.986833
# 2023-02-01 00:15:00         88.0       55.1    0.330000    11.986833
# 2023-02-01 00:30:00         87.7       55.2    0.380000    10.912796
# 2023-02-01 00:45:00         88.9       55.7    0.380000    10.613291
# 2023-02-01 01:00:00         90.0       55.8    0.380000     7.362361
# ...                          ...        ...         ...          ...
# 2023-05-01 22:45:00        100.0       67.8    0.630000    10.000000
# 2023-05-01 23:00:00        100.0       67.7    0.570000    10.000000
# 2023-05-01 23:15:00        100.2       69.2    0.580000     9.900000
# 2023-05-01 23:30:00        100.2       70.2    0.580000     9.500000
# 2023-05-01 23:45:00         98.8       70.3    0.883181    13.054913
#
#                      NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)
# DateTime
# 2023-02-01 00:00:00         17.7           28.1              0.4
# 2023-02-01 00:15:00         18.3           27.1              0.4
# 2023-02-01 00:30:00         19.7           24.9              0.4
# 2023-02-01 00:45:00         21.3           21.9              0.4
# 2023-02-01 01:00:00         22.3           16.7              0.4
# ...                          ...            ...              ...
# 2023-05-01 22:45:00         10.7           26.1              0.1
# 2023-05-01 23:00:00         10.4           30.9              0.1
# 2023-05-01 23:15:00         10.5           29.6              0.1
# 2023-05-01 23:30:00         10.8           30.0              0.1
# 2023-05-01 23:45:00         11.0           33.5              0.1
#
# [8640 rows x 11 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0  PM10 (µg/m3)   NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# count  8640.000000   8640.000000  8640.000000    8640.000000  8640.000000
# mean   4319.500000    165.140621    14.269630      74.626459    56.128353
# std    2494.297496    128.089107    17.986445      54.992383    20.328553
# min       0.000000    -13.488183     0.100000       3.000000     0.200000
# 25%    2159.750000     79.000000     4.000000      36.000000    39.575000
# 50%    4319.500000    127.000000     6.600000      59.000000    53.800000
# 75%    6479.250000    208.000000    17.121285     100.000000    71.500000
# max    8639.000000    847.000000   157.500000     474.000000   106.900000
#
#          NOX (ppb)   CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  Ozone (µg/m3)  \
# count  8640.000000  8640.000000  8640.000000  8640.000000    8640.000000
# mean     42.457154     1.392857    33.727472    13.160495      35.765681
# std      22.129798     0.626985    38.878154     6.095797      26.549469
# min       4.200000     0.100000     0.100000     4.600000       0.100000
# 25%      25.100000     0.930000    15.000000     9.400000      11.000000
# 50%      37.500000     1.390000    24.200000    11.000000      33.000000
# 75%      53.300000     1.832500    36.100000    13.900000      58.125000
# max     165.200000     4.000000   645.600000    62.400000     123.800000
#
#        Benzene (µg/m3)
# count      8640.000000
# mean          0.177505
# std           0.052601
# min           0.100000
# 25%           0.177505
# 50%           0.177505
# 75%           0.177505
# max           0.600000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# PM10 (µg/m3)       0
# NO (µg/m3)         0
# PM2.5 (µg/m3)      0
# NO2 (µg/m3)        0
# NOX (ppb)          0
# CO (mg/m3)         0
# SO2 (µg/m3)        0
# NH3 (µg/m3)        0
# Ozone (µg/m3)      0
# Benzene (µg/m3)    0
# dtype: int64

# %%
df=df.drop('Unnamed: 0',axis=1)

# %% [markdown]
# So we can conclude that there are no missing values in the dataset.
#
# Now we will move forward to plot the timeseries.
#
# To be noted, I have plotted and used the data of PM 10 firstly just to keep it all simple and also since PM 10 is a pollutant which can see maximum fluctuations near a mining site.

# %%
plt.figure(figsize=(20, 10))

plt.plot(df['PM10 (µg/m3)'],label = "PM10")
#plt.plot(df['NO (µg/m3)'],label="NO")
#plt.plot(df['PM2.5 (µg/m3)'],label = "PM2.5")
#plt.plot(df['NO2 (µg/m3)'],label = "NO2")
#plt.plot(df['NOX (ppb)'],label = "NOX")
#plt.plot(df['CO (mg/m3)'],label = "CO")
#plt.plot(df['SO2 (µg/m3)'],label = "SO2")
#plt.plot(df['NH3 (µg/m3)'],label = "NH3")

plt.legend(loc='best')

plt.show()

# %% [markdown]
# Now we will try to smoothen out the data by taking an average of 4 datapoints(1 hour).
#
# Then we will also resample the data to an hourly basis.

# %%
roll = df['PM10 (µg/m3)'].rolling(window = 4).mean()
#roll1 = df['NO (µg/m3)'].rolling(window = 4).mean()
#roll2 = df['PM2.5 (µg/m3)'].rolling(window = 4).mean()
plt.figure(figsize=(20, 10))

plt.plot(roll,label = "PM10")
#plt.plot(roll1,label = "NO")
#plt.plot(roll2,label = "PM2.5")

plt.legend(loc='best')

plt.grid(True)
plt.show()

# %%
df=df.resample('H').mean()

# %%
plt.figure(figsize=(20, 10))

plt.plot(df['PM10 (µg/m3)'],label = "PM10")

plt.legend(loc='best')

plt.grid(True)
plt.show()

# %%
sns.histplot(df['PM10 (µg/m3)'])
# Out:
# <Axes: xlabel='PM10 (µg/m3)', ylabel='Count'>

# %% [markdown]
# From this histogram, we can see that most of the values lie between 0-100 and to be even more precise 0-200. Now this can be considered normal near a coal mining site as even the big cities in India have their average PM10 values near around this only.

# %%
import statsmodels as sm
from statsmodels.tsa.seasonal import seasonal_decompose

pm10_decomposed = seasonal_decompose(df['PM10 (µg/m3)'],model='additive')

plot = pm10_decomposed.plot()

# %% [markdown]
# From this, we can see that there is no specific trend in the data of PM10. There seems to be some sort of seasonality, but that can be termed obvious as coal mining is a daily process.

# %%
df
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00        101.75   15.179643          34.75       88.675
# 2023-02-01 01:00:00        114.00   16.546883          34.25       89.500
# 2023-02-01 02:00:00         85.50   21.454525          34.25       88.875
# 2023-02-01 03:00:00         72.00   19.379084          35.00       86.775
# 2023-02-01 04:00:00         68.50   21.404340          40.00       83.025
# ...                           ...         ...            ...          ...
# 2023-05-01 19:00:00         67.50   11.375000          12.75       97.775
# 2023-05-01 20:00:00         46.25   11.775000           6.50       96.600
# 2023-05-01 21:00:00         31.00   12.075000           7.75       98.075
# 2023-05-01 22:00:00         25.75   15.625000           8.00       98.850
# 2023-05-01 23:00:00         22.25   20.025000           9.75       99.800
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00     55.550    0.350000    11.374938       19.250
# 2023-02-01 01:00:00     55.575    0.360000     8.199097       22.900
# 2023-02-01 02:00:00     55.425    0.385000     8.656719       22.775
# 2023-02-01 03:00:00     54.900    0.432500     8.396549       22.775
# 2023-02-01 04:00:00     52.625    0.397500    13.372907       20.850
# ...                        ...         ...          ...          ...
# 2023-05-01 19:00:00     61.250    0.680000    20.800000        8.700
# 2023-05-01 20:00:00     60.950    0.602500     6.750000        9.975
# 2023-05-01 21:00:00     62.000    0.622500    10.125000       10.525
# 2023-05-01 22:00:00     65.300    0.690000     9.925000       10.800
# 2023-05-01 23:00:00     69.350    0.653295    10.613728       10.675
#
#                      Ozone (µg/m3)  Benzene (µg/m3)
# DateTime
# 2023-02-01 00:00:00         25.500              0.4
# 2023-02-01 01:00:00         18.950              0.4
# 2023-02-01 02:00:00         19.500              0.4
# 2023-02-01 03:00:00         16.425              0.4
# 2023-02-01 04:00:00         17.225              0.4
# ...                            ...              ...
# 2023-05-01 19:00:00         26.100              0.1
# 2023-05-01 20:00:00         34.100              0.1
# 2023-05-01 21:00:00         30.825              0.1
# 2023-05-01 22:00:00         20.750              0.1
# 2023-05-01 23:00:00         31.000              0.1
#
# [2160 rows x 10 columns]

# %%
df["PM10_24hr_avg"] = df["PM10 (µg/m3)"].rolling(window = 24, min_periods = 16).mean().values
df["PM2.5_24hr_avg"] = df["PM2.5 (µg/m3)"].rolling(window = 24, min_periods = 16).mean().values
df["SO2_24hr_avg"] = df["SO2 (µg/m3)"].rolling(window = 24, min_periods = 16).mean().values
df["NOx_24hr_avg"] = df["NOX (ppb)"].rolling(window = 24, min_periods = 16).mean().values
df["NH3_24hr_avg"] = df["NH3 (µg/m3)"].rolling(window = 24, min_periods = 16).mean().values
df["CO_8hr_max"] = df["CO (mg/m3)"].rolling(window = 8, min_periods = 1).max().values
df["O3_8hr_max"] = df["Ozone (µg/m3)"].rolling(window = 8, min_periods = 1).max().values

# %%
df =df.dropna()
df
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00         64.75    5.118280          14.75       60.800
# 2023-02-01 16:00:00         77.50    4.967887          17.75       63.825
# 2023-02-01 17:00:00        111.50    4.592862          25.25       71.175
# 2023-02-01 18:00:00        169.25    4.852657          41.75       82.725
# 2023-02-01 19:00:00        239.00    5.330219          45.50       90.450
# ...                           ...         ...            ...          ...
# 2023-05-01 19:00:00         67.50   11.375000          12.75       97.775
# 2023-05-01 20:00:00         46.25   11.775000           6.50       96.600
# 2023-05-01 21:00:00         31.00   12.075000           7.75       98.075
# 2023-05-01 22:00:00         25.75   15.625000           8.00       98.850
# 2023-05-01 23:00:00         22.25   20.025000           9.75       99.800
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00     35.350    0.305000    49.545184       22.150
# 2023-02-01 16:00:00     38.325    0.285000    29.143486       24.250
# 2023-02-01 17:00:00     42.675    0.417500    20.469569       28.825
# 2023-02-01 18:00:00     49.800    0.502500    17.336271       25.275
# 2023-02-01 19:00:00     54.725    0.605000    15.111777       24.000
# ...                        ...         ...          ...          ...
# 2023-05-01 19:00:00     61.250    0.680000    20.800000        8.700
# 2023-05-01 20:00:00     60.950    0.602500     6.750000        9.975
# 2023-05-01 21:00:00     62.000    0.622500    10.125000       10.525
# 2023-05-01 22:00:00     65.300    0.690000     9.925000       10.800
# 2023-05-01 23:00:00     69.350    0.653295    10.613728       10.675
#
#                      Ozone (µg/m3)  Benzene (µg/m3)  PM10_24hr_avg  \
# DateTime
# 2023-02-01 15:00:00      50.469545              0.1      78.546875
# 2023-02-01 16:00:00      48.850000              0.1      78.485294
# 2023-02-01 17:00:00      38.075000              0.1      80.319444
# 2023-02-01 18:00:00      39.875000              0.1      85.000000
# 2023-02-01 19:00:00      30.400000              0.1      92.700000
# ...                            ...              ...            ...
# 2023-05-01 19:00:00      26.100000              0.1      55.214676
# 2023-05-01 20:00:00      34.100000              0.1      54.287593
# 2023-05-01 21:00:00      30.825000              0.1      52.131343
# 2023-05-01 22:00:00      20.750000              0.1      48.308426
# 2023-05-01 23:00:00      31.000000              0.1      44.020833
#
#                      PM2.5_24hr_avg  SO2_24hr_avg  NOx_24hr_avg  NH3_24hr_avg  \
# DateTime
# 2023-02-01 15:00:00       32.906250     27.461177     46.785347     21.258228
# 2023-02-01 16:00:00       32.014706     27.560136     46.287680     21.434214
# 2023-02-01 17:00:00       31.638889     27.166216     46.086975     21.844813
# 2023-02-01 18:00:00       32.171053     26.648850     46.282397     22.025350
# 2023-02-01 19:00:00       32.837500     26.071996     46.704528     22.124082
# ...                             ...           ...           ...           ...
# 2023-05-01 19:00:00       13.046690     11.919631     57.567490      9.911914
# 2023-05-01 20:00:00       12.692523     11.804006     57.808115      9.863997
# 2023-05-01 21:00:00       12.119606     11.817547     57.865407      9.832747
# 2023-05-01 22:00:00       11.911273     11.926922     57.943532      9.817122
# 2023-05-01 23:00:00       11.375000     12.013381     58.258981      9.799235
#
#                      CO_8hr_max  O3_8hr_max
# DateTime
# 2023-02-01 15:00:00      0.6800   60.809473
# 2023-02-01 16:00:00      0.6800   60.809473
# 2023-02-01 17:00:00      0.6800   60.809473
# 2023-02-01 18:00:00      0.5025   60.809473
# 2023-02-01 19:00:00      0.6050   60.809473
# ...                         ...         ...
# 2023-05-01 19:00:00      0.8150   64.600000
# 2023-05-01 20:00:00      0.8150   64.600000
# 2023-05-01 21:00:00      0.8150   59.175000
# 2023-05-01 22:00:00      0.8150   41.575000
# 2023-05-01 23:00:00      0.8150   41.575000
#
# [2145 rows x 17 columns]

# %%
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5_24hr_avg"].apply(lambda x: get_PM25_subindex(x))

def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x <= 100:
        return x
    elif x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x <= 350:
        return 200 + (x - 250)
    elif x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0

df["PM10_SubIndex"] = df["PM10_24hr_avg"].apply(lambda x: get_PM10_subindex(x))

def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2_24hr_avg"].apply(lambda x: get_SO2_subindex(x))

def get_NOx_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NOx_SubIndex"] = df["NOx_24hr_avg"].apply(lambda x: get_NOx_subindex(x))

def get_NH3_subindex(x):
    if x <= 200:
        return x * 50 / 200
    elif x <= 400:
        return 50 + (x - 200) * 50 / 200
    elif x <= 800:
        return 100 + (x - 400) * 100 / 400
    elif x <= 1200:
        return 200 + (x - 800) * 100 / 400
    elif x <= 1800:
        return 300 + (x - 1200) * 100 / 600
    elif x > 1800:
        return 400 + (x - 1800) * 100 / 600
    else:
        return 0

df["NH3_SubIndex"] = df["NH3_24hr_avg"].apply(lambda x: get_NH3_subindex(x))

def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO_8hr_max"].apply(lambda x: get_CO_subindex(x))

def get_O3_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["O3_SubIndex"] = df["O3_8hr_max"].apply(lambda x: get_O3_subindex(x))
# Out:
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM2.5_SubIndex"] = df["PM2.5_24hr_avg"].apply(lambda x: get_PM25_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM10_SubIndex"] = df["PM10_24hr_avg"].apply(lambda x: get_PM10_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SO2_SubIndex"] = df["SO2_24hr_avg"].apply(lambda x: get_SO2_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NOx_SubIndex"] = df["NOx_24hr_avg"].apply(lambda x: get_NOx_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NH3_SubIndex"] = df["NH3_24hr_avg"].apply(lambda x: get_NH3_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CO_SubIndex"] = df["CO_8hr_max"].apply(lambda x: get_CO_subindex(x))
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1397776218.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["O3_SubIndex"] = df["O3_8hr_max"].apply(lambda x: get_O3_subindex(x))

# %% [markdown]
# Now we will try to plot and analyse the data of PM 10, 1 hour before the blasting time and 1 hour after the blasting time (blasting time is 13:45 - 14:45).
#
# We will try to analyse the results as to how the blasting affects the values of PM 10 in the environment.

# %%
def get_AQI_bucket(x):
    if x <= 50:
        return "Good"
    elif x <= 100:
        return "Satisfactory"
    elif x <= 200:
        return "Moderate"
    elif x <= 300:
        return "Poor"
    elif x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return np.NaN
    
df["Checks"] = (df["PM2.5_SubIndex"] > 0).astype(int) + \
                (df["PM10_SubIndex"] > 0).astype(int) + \
                (df["SO2_SubIndex"] > 0).astype(int) + \
                (df["NOx_SubIndex"] > 0).astype(int) + \
                (df["NH3_SubIndex"] > 0).astype(int) + \
                (df["CO_SubIndex"] > 0).astype(int) + \
                (df["O3_SubIndex"] > 0).astype(int)

df["AQI_calculated"] = round(df[["PM2.5_SubIndex", "PM10_SubIndex", "SO2_SubIndex", "NOx_SubIndex",
                                 "NH3_SubIndex", "CO_SubIndex", "O3_SubIndex"]].max(axis = 1))
df.loc[df["PM2.5_SubIndex"] + df["PM10_SubIndex"] <= 0, "AQI_calculated"] = np.NaN
df.loc[df.Checks < 3, "AQI_calculated"] = np.NaN

df["AQI_bucket_calculated"] = df["AQI_calculated"].apply(lambda x: get_AQI_bucket(x))
df[~df.AQI_calculated.isna()]
# Out:
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1469702955.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Checks"] = (df["PM2.5_SubIndex"] > 0).astype(int) + \
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1469702955.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI_calculated"] = round(df[["PM2.5_SubIndex", "PM10_SubIndex", "SO2_SubIndex", "NOx_SubIndex",
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\1469702955.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI_bucket_calculated"] = df["AQI_calculated"].apply(lambda x: get_AQI_bucket(x))
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00         64.75    5.118280          14.75       60.800
# 2023-02-01 16:00:00         77.50    4.967887          17.75       63.825
# 2023-02-01 17:00:00        111.50    4.592862          25.25       71.175
# 2023-02-01 18:00:00        169.25    4.852657          41.75       82.725
# 2023-02-01 19:00:00        239.00    5.330219          45.50       90.450
# ...                           ...         ...            ...          ...
# 2023-05-01 19:00:00         67.50   11.375000          12.75       97.775
# 2023-05-01 20:00:00         46.25   11.775000           6.50       96.600
# 2023-05-01 21:00:00         31.00   12.075000           7.75       98.075
# 2023-05-01 22:00:00         25.75   15.625000           8.00       98.850
# 2023-05-01 23:00:00         22.25   20.025000           9.75       99.800
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00     35.350    0.305000    49.545184       22.150
# 2023-02-01 16:00:00     38.325    0.285000    29.143486       24.250
# 2023-02-01 17:00:00     42.675    0.417500    20.469569       28.825
# 2023-02-01 18:00:00     49.800    0.502500    17.336271       25.275
# 2023-02-01 19:00:00     54.725    0.605000    15.111777       24.000
# ...                        ...         ...          ...          ...
# 2023-05-01 19:00:00     61.250    0.680000    20.800000        8.700
# 2023-05-01 20:00:00     60.950    0.602500     6.750000        9.975
# 2023-05-01 21:00:00     62.000    0.622500    10.125000       10.525
# 2023-05-01 22:00:00     65.300    0.690000     9.925000       10.800
# 2023-05-01 23:00:00     69.350    0.653295    10.613728       10.675
#
#                      Ozone (µg/m3)  Benzene (µg/m3)  ...  PM2.5_SubIndex  \
# DateTime                                             ...
# 2023-02-01 15:00:00      50.469545              0.1  ...       54.843750
# 2023-02-01 16:00:00      48.850000              0.1  ...       53.357843
# 2023-02-01 17:00:00      38.075000              0.1  ...       52.731481
# 2023-02-01 18:00:00      39.875000              0.1  ...       53.618421
# 2023-02-01 19:00:00      30.400000              0.1  ...       54.729167
# ...                            ...              ...  ...             ...
# 2023-05-01 19:00:00      26.100000              0.1  ...       21.744483
# 2023-05-01 20:00:00      34.100000              0.1  ...       21.154205
# 2023-05-01 21:00:00      30.825000              0.1  ...       20.199344
# 2023-05-01 22:00:00      20.750000              0.1  ...       19.852122
# 2023-05-01 23:00:00      31.000000              0.1  ...       18.958333
#
#                      PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  \
# DateTime
# 2023-02-01 15:00:00      78.546875     34.326471     58.481684      5.314557
# 2023-02-01 16:00:00      78.485294     34.450170     57.859599      5.358554
# 2023-02-01 17:00:00      80.319444     33.957769     57.608719      5.461203
# 2023-02-01 18:00:00      85.000000     33.311063     57.852997      5.506337
# 2023-02-01 19:00:00      92.700000     32.589996     58.380660      5.531021
# ...                            ...           ...           ...           ...
# 2023-05-01 19:00:00      55.214676     14.899538     71.959362      2.477978
# 2023-05-01 20:00:00      54.287593     14.755007     72.260144      2.465999
# 2023-05-01 21:00:00      52.131343     14.771934     72.331758      2.458187
# 2023-05-01 22:00:00      48.308426     14.908653     72.429415      2.454281
# 2023-05-01 23:00:00      44.020833     15.016726     72.823727      2.449809
#
#                      CO_SubIndex  O3_SubIndex  Checks  AQI_calculated  \
# DateTime
# 2023-02-01 15:00:00       34.000    60.809473       7            79.0
# 2023-02-01 16:00:00       34.000    60.809473       7            78.0
# 2023-02-01 17:00:00       34.000    60.809473       7            80.0
# 2023-02-01 18:00:00       25.125    60.809473       7            85.0
# 2023-02-01 19:00:00       30.250    60.809473       7            93.0
# ...                          ...          ...     ...             ...
# 2023-05-01 19:00:00       40.750    64.600000       7            72.0
# 2023-05-01 20:00:00       40.750    64.600000       7            72.0
# 2023-05-01 21:00:00       40.750    59.175000       7            72.0
# 2023-05-01 22:00:00       40.750    41.575000       7            72.0
# 2023-05-01 23:00:00       40.750    41.575000       7            73.0
#
#                      AQI_bucket_calculated
# DateTime
# 2023-02-01 15:00:00           Satisfactory
# 2023-02-01 16:00:00           Satisfactory
# 2023-02-01 17:00:00           Satisfactory
# 2023-02-01 18:00:00           Satisfactory
# 2023-02-01 19:00:00           Satisfactory
# ...                                    ...
# 2023-05-01 19:00:00           Satisfactory
# 2023-05-01 20:00:00           Satisfactory
# 2023-05-01 21:00:00           Satisfactory
# 2023-05-01 22:00:00           Satisfactory
# 2023-05-01 23:00:00           Satisfactory
#
# [2145 rows x 27 columns]

# %%
df[~df.AQI_calculated.isna()].AQI_bucket_calculated.value_counts()
# Out:
# Moderate        1214
# Poor             484
# Satisfactory     262
# Very Poor        171
# Severe            14
# Name: AQI_bucket_calculated, dtype: int64

# %%
df
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00         64.75    5.118280          14.75       60.800
# 2023-02-01 16:00:00         77.50    4.967887          17.75       63.825
# 2023-02-01 17:00:00        111.50    4.592862          25.25       71.175
# 2023-02-01 18:00:00        169.25    4.852657          41.75       82.725
# 2023-02-01 19:00:00        239.00    5.330219          45.50       90.450
# ...                           ...         ...            ...          ...
# 2023-05-01 19:00:00         67.50   11.375000          12.75       97.775
# 2023-05-01 20:00:00         46.25   11.775000           6.50       96.600
# 2023-05-01 21:00:00         31.00   12.075000           7.75       98.075
# 2023-05-01 22:00:00         25.75   15.625000           8.00       98.850
# 2023-05-01 23:00:00         22.25   20.025000           9.75       99.800
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00     35.350    0.305000    49.545184       22.150
# 2023-02-01 16:00:00     38.325    0.285000    29.143486       24.250
# 2023-02-01 17:00:00     42.675    0.417500    20.469569       28.825
# 2023-02-01 18:00:00     49.800    0.502500    17.336271       25.275
# 2023-02-01 19:00:00     54.725    0.605000    15.111777       24.000
# ...                        ...         ...          ...          ...
# 2023-05-01 19:00:00     61.250    0.680000    20.800000        8.700
# 2023-05-01 20:00:00     60.950    0.602500     6.750000        9.975
# 2023-05-01 21:00:00     62.000    0.622500    10.125000       10.525
# 2023-05-01 22:00:00     65.300    0.690000     9.925000       10.800
# 2023-05-01 23:00:00     69.350    0.653295    10.613728       10.675
#
#                      Ozone (µg/m3)  Benzene (µg/m3)  ...  PM2.5_SubIndex  \
# DateTime                                             ...
# 2023-02-01 15:00:00      50.469545              0.1  ...       54.843750
# 2023-02-01 16:00:00      48.850000              0.1  ...       53.357843
# 2023-02-01 17:00:00      38.075000              0.1  ...       52.731481
# 2023-02-01 18:00:00      39.875000              0.1  ...       53.618421
# 2023-02-01 19:00:00      30.400000              0.1  ...       54.729167
# ...                            ...              ...  ...             ...
# 2023-05-01 19:00:00      26.100000              0.1  ...       21.744483
# 2023-05-01 20:00:00      34.100000              0.1  ...       21.154205
# 2023-05-01 21:00:00      30.825000              0.1  ...       20.199344
# 2023-05-01 22:00:00      20.750000              0.1  ...       19.852122
# 2023-05-01 23:00:00      31.000000              0.1  ...       18.958333
#
#                      PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  \
# DateTime
# 2023-02-01 15:00:00      78.546875     34.326471     58.481684      5.314557
# 2023-02-01 16:00:00      78.485294     34.450170     57.859599      5.358554
# 2023-02-01 17:00:00      80.319444     33.957769     57.608719      5.461203
# 2023-02-01 18:00:00      85.000000     33.311063     57.852997      5.506337
# 2023-02-01 19:00:00      92.700000     32.589996     58.380660      5.531021
# ...                            ...           ...           ...           ...
# 2023-05-01 19:00:00      55.214676     14.899538     71.959362      2.477978
# 2023-05-01 20:00:00      54.287593     14.755007     72.260144      2.465999
# 2023-05-01 21:00:00      52.131343     14.771934     72.331758      2.458187
# 2023-05-01 22:00:00      48.308426     14.908653     72.429415      2.454281
# 2023-05-01 23:00:00      44.020833     15.016726     72.823727      2.449809
#
#                      CO_SubIndex  O3_SubIndex  Checks  AQI_calculated  \
# DateTime
# 2023-02-01 15:00:00       34.000    60.809473       7            79.0
# 2023-02-01 16:00:00       34.000    60.809473       7            78.0
# 2023-02-01 17:00:00       34.000    60.809473       7            80.0
# 2023-02-01 18:00:00       25.125    60.809473       7            85.0
# 2023-02-01 19:00:00       30.250    60.809473       7            93.0
# ...                          ...          ...     ...             ...
# 2023-05-01 19:00:00       40.750    64.600000       7            72.0
# 2023-05-01 20:00:00       40.750    64.600000       7            72.0
# 2023-05-01 21:00:00       40.750    59.175000       7            72.0
# 2023-05-01 22:00:00       40.750    41.575000       7            72.0
# 2023-05-01 23:00:00       40.750    41.575000       7            73.0
#
#                      AQI_bucket_calculated
# DateTime
# 2023-02-01 15:00:00           Satisfactory
# 2023-02-01 16:00:00           Satisfactory
# 2023-02-01 17:00:00           Satisfactory
# 2023-02-01 18:00:00           Satisfactory
# 2023-02-01 19:00:00           Satisfactory
# ...                                    ...
# 2023-05-01 19:00:00           Satisfactory
# 2023-05-01 20:00:00           Satisfactory
# 2023-05-01 21:00:00           Satisfactory
# 2023-05-01 22:00:00           Satisfactory
# 2023-05-01 23:00:00           Satisfactory
#
# [2145 rows x 27 columns]

# %%
m = len(df)
print(m)
# Out:
# 2145

# %%
column_name = 'AQI_bucket_calculated'
desired_value = ['Severe' , 'Very Poor']

filtered_df = df[df[column_name].isin(desired_value)]

# %%
plt.figure(figsize=(20, 10))
plt.plot(df['AQI_calculated'],label = "AQI")

# %%
df['hour'] =df.index.hour

# Create a pivot table with 'hour' as columns and 'datetime' as index
pivot_table_df =df.pivot_table(index=df.index.date, 
                                            columns='hour', 
                                            values='AQI_calculated', 
                                            fill_value=None)
hour_column_names = [f'hour_{hour}' for hour in range(24)]

# Rename the columns of the pivot table
pivot_table_df.columns = hour_column_names
pivot_table_df.head()
# Out:
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_15556\349127526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] =df.index.hour
#             hour_0  hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  hour_7  \
# 2023-02-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-02-02   112.0   113.0   116.0   119.0   120.0   121.0   122.0   122.0
# 2023-02-03   153.0   153.0   152.0   151.0   152.0   154.0   156.0   158.0
# 2023-02-04   147.0   148.0   150.0   151.0   151.0   150.0   148.0   149.0
# 2023-02-05   172.0   175.0   178.0   184.0   189.0   191.0   192.0   191.0
#
#             hour_8  hour_9  ...  hour_14  hour_15  hour_16  hour_17  hour_18  \
# 2023-02-01     NaN     NaN  ...      NaN     79.0     78.0     80.0     85.0
# 2023-02-02   123.0   124.0  ...    131.0    133.0    134.0    135.0    134.0
# 2023-02-03   159.0   160.0  ...    163.0    162.0    162.0    162.0    164.0
# 2023-02-04   156.0   163.0  ...    161.0    160.0    160.0    160.0    160.0
# 2023-02-05   190.0   185.0  ...    186.0    187.0    184.0    182.0    180.0
#
#             hour_19  hour_20  hour_21  hour_22  hour_23
# 2023-02-01     93.0    100.0    104.0    107.0    110.0
# 2023-02-02    133.0    138.0    144.0    149.0    152.0
# 2023-02-03    164.0    159.0    154.0    149.0    148.0
# 2023-02-04    160.0    159.0    160.0    165.0    169.0
# 2023-02-05    177.0    180.0    184.0    186.0    189.0
#
# [5 rows x 24 columns]

# %%
averages = pivot_table_df.mean(axis=0)

# Create a new DataFrame with the averages
averages_df = pd.DataFrame(averages, columns=['average'])

# Print the new DataFrame with the averages
print(averages_df)
# Out:
#             average
# hour_0   175.662921
# hour_1   175.404494
# hour_2   174.865169
# hour_3   174.483146
# hour_4   174.191011
# hour_5   174.033708
# hour_6   173.887640
# hour_7   174.191011
# hour_8   174.505618
# hour_9   174.539326
# hour_10  174.640449
# hour_11  174.595506
# hour_12  174.539326
# hour_13  174.539326
# hour_14  174.887640
# hour_15  174.144444
# hour_16  174.477778
# hour_17  174.922222
# hour_18  174.511111
# hour_19  175.011111
# hour_20  174.255556
# hour_21  174.133333
# hour_22  174.144444
# hour_23  174.255556

# %%
hour_numbers = [int(idx.split('_')[1]) for idx in averages_df.index]
datetime_index = pd.to_datetime(hour_numbers, format='%H').time

# Assign the new datetime index to the DataFrame
averages_df.index = datetime_index

print(averages_df)
# Out:
#              average
# 00:00:00  175.662921
# 01:00:00  175.404494
# 02:00:00  174.865169
# 03:00:00  174.483146
# 04:00:00  174.191011
# 05:00:00  174.033708
# 06:00:00  173.887640
# 07:00:00  174.191011
# 08:00:00  174.505618
# 09:00:00  174.539326
# 10:00:00  174.640449
# 11:00:00  174.595506
# 12:00:00  174.539326
# 13:00:00  174.539326
# 14:00:00  174.887640
# 15:00:00  174.144444
# 16:00:00  174.477778
# 17:00:00  174.922222
# 18:00:00  174.511111
# 19:00:00  175.011111
# 20:00:00  174.255556
# 21:00:00  174.133333
# 22:00:00  174.144444
# 23:00:00  174.255556

# %% [markdown]
# We can see that the local maxima is around 14:00:00 so the blasting time must be around it.

# %%
print(type(averages_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import datetime

blasting_time = datetime.time(14, 0, 0)
from scipy.stats import gaussian_kde
kde = gaussian_kde(averages_df, bw_method=0.04)  # You can adjust the bandwidth (bw_method) for smoothness

# Create a range of time values around the "blasting_time"
time_range = np.linspace(blasting_time - np.timedelta64(7, 'm'), blasting_time + np.timedelta64(7, 'm'), 1000)

# Calculate the probability density values at the time range
probability_density = kde(time_range)

# Find the probability of blasting happening in a nearby time frame of 15 min
time_window = np.timedelta64(15, 'm')
index_blasting_time = np.argmin(np.abs(time_range - blasting_time))
index_nearby_time_frame = np.abs(time_range - blasting_time) < time_window
probability_nearby_time_frame = np.trapz(probability_density[index_nearby_time_frame], time_range[index_nearby_time_frame])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 5
#       3 blasting_time = datetime.time(14, 0, 0)
#       4 from scipy.stats import gaussian_kde
# ----> 5 kde = gaussian_kde(averages_df, bw_method=0.04)  # You can adjust the bandwidth (bw_method) for smoothness
#       7 # Create a range of time values around the "blasting_time"
#       8 time_range = np.linspace(blasting_time - np.timedelta64(7, 'm'), blasting_time + np.timedelta64(7, 'm'), 1000)
#
# File c:\Users\Anya Rajan\anaconda4\lib\site-packages\scipy\stats\_kde.py:220, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     213 if self.d > self.n:
#     214     msg = ("Number of dimensions is greater than number of samples. "
#     215            "This results in a singular data covariance matrix, which "
#     216            "cannot be treated using the algorithms implemented in "
#     217            "`gaussian_kde`. Note that `gaussian_kde` interprets each "
#     218            "*column* of `dataset` to be a point; consider transposing "
#     219            "the input to `dataset`.")
# --> 220     raise ValueError(msg)
#     222 try:
#     223     self.set_bandwidth(bw_method=bw_method)
#
# ValueError: Number of dimensions is greater than number of samples. This results in a singular data covariance matrix, which cannot be treated using the algorithms implemented in `gaussian_kde`. Note that `gaussian_kde` interprets each *column* of `dataset` to be a point; consider transposing the input to `dataset`.

# %% [markdown]
# In this code we are getting an error when calculating probablility. We tried other methods as well but it didn't work. So we have shown the code as our effort.

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df'

# Plot the DataFrame
averages_df.plot()

# Display the plot
plt.show()

# %% [markdown]
# This graph gives us very important insights that the pollution reaches a local maxima during the daytime of 1300-1400 hours which can be related to the blasting time of the mines.

# %%
average_value = pivot_table_df['hour_0'].mean()
print("Average:", average_value)
# Out:
# Average: 175.6629213483146

# %%
hourly_groups = df.groupby(pd.Grouper(key='DateTime', freq='H'))
# for hour, group in hourly_groups:
#     print(f"Hour: {hour}")
#     print(group)
print(hourly_groups)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000023F20D772B0>

# %%
df.head()
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00         64.75    5.118280          14.75       60.800
# 2023-02-01 16:00:00         77.50    4.967887          17.75       63.825
# 2023-02-01 17:00:00        111.50    4.592862          25.25       71.175
# 2023-02-01 18:00:00        169.25    4.852657          41.75       82.725
# 2023-02-01 19:00:00        239.00    5.330219          45.50       90.450
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 15:00:00     35.350      0.3050    49.545184       22.150
# 2023-02-01 16:00:00     38.325      0.2850    29.143486       24.250
# 2023-02-01 17:00:00     42.675      0.4175    20.469569       28.825
# 2023-02-01 18:00:00     49.800      0.5025    17.336271       25.275
# 2023-02-01 19:00:00     54.725      0.6050    15.111777       24.000
#
#                      Ozone (µg/m3)  Benzene (µg/m3)  ...  PM10_SubIndex  \
# DateTime                                             ...
# 2023-02-01 15:00:00      50.469545              0.1  ...      78.546875
# 2023-02-01 16:00:00      48.850000              0.1  ...      78.485294
# 2023-02-01 17:00:00      38.075000              0.1  ...      80.319444
# 2023-02-01 18:00:00      39.875000              0.1  ...      85.000000
# 2023-02-01 19:00:00      30.400000              0.1  ...      92.700000
#
#                      SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  CO_SubIndex  \
# DateTime
# 2023-02-01 15:00:00     34.326471     58.481684      5.314557       34.000
# 2023-02-01 16:00:00     34.450170     57.859599      5.358554       34.000
# 2023-02-01 17:00:00     33.957769     57.608719      5.461203       34.000
# 2023-02-01 18:00:00     33.311063     57.852997      5.506337       25.125
# 2023-02-01 19:00:00     32.589996     58.380660      5.531021       30.250
#
#                      O3_SubIndex  Checks  AQI_calculated  \
# DateTime
# 2023-02-01 15:00:00    60.809473       7            79.0
# 2023-02-01 16:00:00    60.809473       7            78.0
# 2023-02-01 17:00:00    60.809473       7            80.0
# 2023-02-01 18:00:00    60.809473       7            85.0
# 2023-02-01 19:00:00    60.809473       7            93.0
#
#                      AQI_bucket_calculated            DateTime
# DateTime
# 2023-02-01 15:00:00           Satisfactory 2023-02-01 15:00:00
# 2023-02-01 16:00:00           Satisfactory 2023-02-01 16:00:00
# 2023-02-01 17:00:00           Satisfactory 2023-02-01 17:00:00
# 2023-02-01 18:00:00           Satisfactory 2023-02-01 18:00:00
# 2023-02-01 19:00:00           Satisfactory 2023-02-01 19:00:00
#
# [5 rows x 28 columns]

# %%
df['date'] = df['DateTime'].dt.date

daywise_data = {}

# Iterate over unique dates and group the data by each day
for date in df['date'].unique():
    day_data = df[df['date'] == date].copy()
    day_data.drop('date', axis=1, inplace=True)
    daywise_data[date] = day_data

# Print day-wise hourly data for the first few days
for date, data in list(daywise_data.items())[:3]:
    print(f"Day: {date}")
data.head()
# Out:
# C:\Users\Anya Rajan\AppData\Local\Temp\ipykernel_4436\1249253742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['DateTime'].dt.date
# Day: 2023-02-01
# Day: 2023-02-02
# Day: 2023-02-03
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-03 00:00:00        215.00   15.214341          61.00       83.250
# 2023-02-03 01:00:00        156.00   16.546883          65.75       76.975
# 2023-02-03 02:00:00        150.00   21.454525          60.50       76.950
# 2023-02-03 03:00:00        143.00   19.379084          57.50       76.050
# 2023-02-03 04:00:00        129.25   21.404340          65.75       76.175
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-03 00:00:00     71.550      1.3350    11.374938       18.575
# 2023-02-03 01:00:00     63.100      1.1750     8.199097       23.575
# 2023-02-03 02:00:00     59.225      1.1625     8.656719       26.325
# 2023-02-03 03:00:00     56.600      1.2175     8.396549       25.675
# 2023-02-03 04:00:00     57.700      1.4125    13.372907       25.475
#
#                      Ozone (µg/m3)  Benzene (µg/m3)  ...  PM10_SubIndex  \
# DateTime                                             ...
# 2023-02-03 00:00:00         15.600              0.2  ...     152.888889
# 2023-02-03 01:00:00         16.050              0.2  ...     152.861111
# 2023-02-03 02:00:00         11.675              0.2  ...     151.750000
# 2023-02-03 03:00:00         11.075              0.2  ...     150.979167
# 2023-02-03 04:00:00          4.750              0.2  ...     151.576389
#
#                      SO2_SubIndex  NOx_SubIndex  NH3_SubIndex  CO_SubIndex  \
# DateTime
# 2023-02-03 00:00:00     30.588689     67.934224      5.481934       95.375
# 2023-02-03 01:00:00     30.588689     68.460266      5.482194       95.375
# 2023-02-03 02:00:00     30.588689     68.790995      5.499903       95.375
# 2023-02-03 03:00:00     30.588689     69.149068      5.509017       93.000
# 2023-02-03 04:00:00     30.588689     69.723287      5.520736       93.000
#
#                      O3_SubIndex  Checks  AQI_calculated  \
# DateTime
# 2023-02-03 00:00:00        43.15       7           153.0
# 2023-02-03 01:00:00        16.05       7           153.0
# 2023-02-03 02:00:00        16.05       7           152.0
# 2023-02-03 03:00:00        16.05       7           151.0
# 2023-02-03 04:00:00        16.05       7           152.0
#
#                      AQI_bucket_calculated            DateTime
# DateTime
# 2023-02-03 00:00:00               Moderate 2023-02-03 00:00:00
# 2023-02-03 01:00:00               Moderate 2023-02-03 01:00:00
# 2023-02-03 02:00:00               Moderate 2023-02-03 02:00:00
# 2023-02-03 03:00:00               Moderate 2023-02-03 03:00:00
# 2023-02-03 04:00:00               Moderate 2023-02-03 04:00:00
#
# [5 rows x 28 columns]

# %%
mean13=0

for i in range(1,450,5):
    mean13=mean13+ df_time_periods['PM10 (µg/m3)'][i]
mean13=mean13/90

df_plot = df_time_periods[df_time_periods['time_period'] == '13:00']
plt.figure(figsize=(20, 10))

plt.plot(df_plot.index, df_plot['PM10 (µg/m3)'],label='PM 10')
plt.axhline(mean13,color='r', linestyle='-', label='Average PM 10')

plt.title(f"Data for 13:00")
plt.xlabel("Date")
plt.ylabel("PM10")
plt.legend(loc='best')

plt.show()

# %%
mean14=0

for i in range(2,450,5):
    mean14=mean14+ df_time_periods['PM10 (µg/m3)'][i]
mean14=mean14/90

df_plot = df_time_periods[df_time_periods['time_period'] == '14:00']
plt.figure(figsize=(20, 10))

plt.plot(df_plot.index, df_plot['PM10 (µg/m3)'],label='PM 10')
plt.axhline(mean14,color='r', linestyle='-', label='Average PM 10')

plt.title(f"Data for 14:00")
plt.xlabel("Date")
plt.ylabel("PM10")
plt.legend(loc='best')

plt.show()

# %%
mean15=0

for i in range(3,450,5):
    mean15=mean15+ df_time_periods['PM10 (µg/m3)'][i]
mean15=mean15/90

df_plot = df_time_periods[df_time_periods['time_period'] == '15:00']
plt.figure(figsize=(20, 10))

plt.plot(df_plot.index, df_plot['PM10 (µg/m3)'],label='PM 10')
plt.axhline(mean15,color='r', linestyle='-', label='Average PM 10')

plt.title(f"Data for 15:00")
plt.xlabel("Date")
plt.ylabel("PM10")
plt.legend(loc='best')

plt.show()

# %%
mean16=0

for i in range(4,450,5):
    mean16=mean16+ df_time_periods['PM10 (µg/m3)'][i]
mean16=mean16/90

df_plot = df_time_periods[df_time_periods['time_period'] == '16:00']
plt.figure(figsize=(20, 10))

plt.plot(df_plot.index, df_plot['PM10 (µg/m3)'],label='PM 10')
plt.axhline(mean16,color='r', linestyle='-', label='Average PM 10')

plt.title(f"Data for 16:00")
plt.xlabel("Date")
plt.ylabel("PM10")
plt.legend(loc='best')

plt.show()

# %%
df_time_periods
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 12:00:00         63.25    4.816976          23.00       63.525
# 2023-02-01 13:00:00         64.00    5.431987          21.75       62.100
# 2023-02-01 14:00:00         70.50    5.546167          17.00       60.425
# 2023-02-01 15:00:00         64.75    5.118280          14.75       60.800
# 2023-02-01 16:00:00         77.50    4.967887          17.75       63.825
# ...                           ...         ...            ...          ...
# 2023-05-01 12:00:00         36.00    2.675000          10.00       78.500
# 2023-05-01 13:00:00         28.50    2.675000           6.25       79.375
# 2023-05-01 14:00:00         16.50    3.775000           5.00       82.200
# 2023-05-01 15:00:00         26.50    7.225000           8.00       87.175
# 2023-05-01 16:00:00         45.00    8.000000           8.50       90.300
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 12:00:00     36.075      0.2550    51.079797       23.475
# 2023-02-01 13:00:00     35.450      0.2200    53.493204       20.400
# 2023-02-01 14:00:00     34.800      0.3325    36.797048       21.250
# 2023-02-01 15:00:00     35.350      0.3050    49.545184       22.150
# 2023-02-01 16:00:00     38.325      0.2850    29.143486       24.250
# ...                        ...         ...          ...          ...
# 2023-05-01 12:00:00     43.975      0.6050     9.325000       12.375
# 2023-05-01 13:00:00     44.400      0.5550     7.250000       10.275
# 2023-05-01 14:00:00     46.750      0.5725    15.000000        9.400
# 2023-05-01 15:00:00     52.250      0.5775    74.725000        9.775
# 2023-05-01 16:00:00     54.525      0.6425    18.175000        8.850
#
#                      Ozone (µg/m3)  Benzene (µg/m3) time_period
# DateTime
# 2023-02-01 12:00:00      60.809473              0.1       12:00
# 2023-02-01 13:00:00      57.575000              0.1       13:00
# 2023-02-01 14:00:00      56.300000              0.1       14:00
# 2023-02-01 15:00:00      50.469545              0.1       15:00
# 2023-02-01 16:00:00      48.850000              0.1       16:00
# ...                            ...              ...         ...
# 2023-05-01 12:00:00      63.425000              0.1       12:00
# 2023-05-01 13:00:00      64.600000              0.1       13:00
# 2023-05-01 14:00:00      59.175000              0.1       14:00
# 2023-05-01 15:00:00      33.875000              0.1       15:00
# 2023-05-01 16:00:00      41.575000              0.1       16:00
#
# [450 rows x 11 columns]

# %%
avg = {'avg_pm10_12:00':mean12,
       'avg_pm10_13:00':mean13,
       'avg_pm10_14:00':mean14,
       'avg_pm10_15:00:':mean15,
       'avg_pm10_16:00':mean16}
avg
# Out:
# {'avg_pm10_12:00': 121.50225178527775,
#  'avg_pm10_13:00': 106.99555353721783,
#  'avg_pm10_14:00': 97.52821446041541,
#  'avg_pm10_15:00:': 86.89811627333887,
#  'avg_pm10_16:00': 90.27346436626863}

# %% [markdown]
# From this, we can tell that when the time is for blasting in the coal mines, the average value of PM 10 is lower comparitive to other times.
#
# Just to get a better visualisation, we will plot the data of the average PM 10 values of all the hours in the day.
#
# This will lead us to better insights.

# %%
listx=[]
for i in range(24):
    listx.append(i)
avg_df = pd.DataFrame(listx)
avg_df['PM10 (µg/m3)'] = 0
avg_df['NO (µg/m3)'] = 0
avg_df['PM2.5 (µg/m3)'] = 0
avg_df['NO2 (µg/m3)'] = 0
avg_df['CO (mg/m3)'] = 0
avg_df['NH3 (µg/m3)'] = 0
avg_df['Ozone (µg/m3)'] = 0
avg_df['Benzene (µg/m3)'] = 0
avg_df['NOX (ppb)'] = 0
avg_df['SO2 (µg/m3)'] = 0

avg_df=avg_df.drop(columns=0)

for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['PM10 (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'PM10 (µg/m3)']= meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['NO (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'NO (µg/m3)'] = meanx    
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['PM2.5 (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'PM2.5 (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['NO2 (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'NO2 (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['CO (mg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'CO (mg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['NH3 (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'NH3 (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['Ozone (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'Ozone (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['Benzene (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'Benzene (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['SO2 (µg/m3)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'SO2 (µg/m3)'] = meanx
    
for x in range(24):
    meanx=0
    for i in range(x,2160,24):
        meanx=meanx+ df['NOX (ppb)'][i]
        
    meanx=meanx/90
    
    avg_df.loc[x, 'NOX (ppb)'] = meanx



plt.figure(figsize=(20, 10))
plt.plot(avg_df['PM10 (µg/m3)'],label = "PM 10")
plt.plot(avg_df['PM2.5 (µg/m3)'],label = "PM 2.5")
plt.plot(avg_df['NO (µg/m3)'],label = "NO")
plt.plot(avg_df['Ozone (µg/m3)'],label = "Ozone")
plt.plot(avg_df['SO2 (µg/m3)'],label = "SO2")
plt.plot(avg_df['NO2 (µg/m3)'],label = "NO2")

plt.xlabel("Time in 24hrs")
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# So from this, we can see that there are different patterns that are being formed with different pollutants at different times.
#
# One thing that is common between all of them is that either they rise during the time period of around 1000 hrs to 2000 hrs or they fall during these hours.
#
# We will further try to classify what all pollutants see a rise during the blasting hours and which one see a fall.
#
# Since mining is a process which is carried out 24 hours of tha day, it is essential to note that we see a dip or a peak at some given times.
#
# For instance, PM 10 and PM 2.5 both reach there lowest while Ozone reaches its peak at 1500 hours of the day, which to be noted is 15 minutes after the designated blasting time of the coal mine.

# %%
plt.figure(figsize=(20, 10))

plt.plot(avg_df['CO (mg/m3)'],label = "CO")
plt.plot(avg_df['Benzene (µg/m3)'],label = "Benzene")

plt.xlabel("Time in 24hrs")
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.plot(avg_df['NOX (ppb)'],label = "NOx")
plt.plot(avg_df['NH3 (µg/m3)'],label = "NH3")

plt.xlabel("Time in 24hrs")
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# From the above graphs, we infer the following that around blasting time, there is
#
# # Rise
#
# 1. Ozone
# 2. SO2
#
# # Fall
#
# 1. PM 10
# 2. PM 2.5
# 3. NO
# 4. NOx
# 5. CO
# 6. Benzene
#
# # No Change
#
# 1. NH3
# 2. NO2
#
# We however notice that there are some other peaks also being created.
#
# One peak is being vreated at around 0700 hrs and another is beaing created at around 2100 hrs, while one dip(as we noticed), is beaing created around 1400-1500 hrs.
#
# One interesting observation (and probably a corelation) that can be made is that, mining in Coal India takes place in 3 shifts of 8 hours. The shifts are as follows-
#
# 0500 - 1300
#
# 1300 - 2100
#
# 2100 - 0500

# %% [markdown]
# Now let us make a single time series by weighted combination of the polluting factors. For that, first let us find the standard deviation in the values of the pollutants averaged at all the hours of the day.
#
# More the standard deviation, more the weight should be assigned to the pollutant. Then we can create a single times series that measures the pollution effect throughout the day.

# %%
sumstd = ((avg_df['PM10 (µg/m3)'].std())/avg_df['PM10 (µg/m3)'].mean() + (avg_df['NO (µg/m3)'].std())/avg_df['NO (µg/m3)'].mean() + (avg_df['PM2.5 (µg/m3)'].std())/avg_df['PM2.5 (µg/m3)'].mean() + (avg_df['NO2 (µg/m3)'].std())/avg_df['NO2 (µg/m3)'].mean()
         + (avg_df['CO (mg/m3)'].std())/avg_df['CO (mg/m3)'].mean() + (avg_df['NH3 (µg/m3)'].std())/avg_df['NH3 (µg/m3)'].mean() + (avg_df['Ozone (µg/m3)'].std())/avg_df['Ozone (µg/m3)'].mean() + (avg_df['Benzene (µg/m3)'].std())/avg_df['Benzene (µg/m3)'].mean()+
         (avg_df['NOX (ppb)'].std())/avg_df['NOX (ppb)'].mean() + (avg_df['SO2 (µg/m3)'].std())/avg_df['SO2 (µg/m3)'].mean())

std_wt = {'std_pm10':((avg_df['PM10 (µg/m3)'].std())/avg_df['PM10 (µg/m3)'].mean())/sumstd,
      'std_no':((avg_df['NO (µg/m3)'].std())/avg_df['NO (µg/m3)'].mean())/sumstd,
      'std_pm2.5':((avg_df['PM2.5 (µg/m3)'].std())/avg_df['PM2.5 (µg/m3)'].mean())/sumstd,
      'std_no2':((avg_df['NO2 (µg/m3)'].std())/avg_df['NO2 (µg/m3)'].mean())/sumstd,
      'std_co':((avg_df['CO (mg/m3)'].std())/avg_df['CO (mg/m3)'].mean())/sumstd,
      'std_nh3':((avg_df['NH3 (µg/m3)'].std())/avg_df['NH3 (µg/m3)'].mean())/sumstd,
      'std_ozone':((avg_df['Ozone (µg/m3)'].std())/avg_df['Ozone (µg/m3)'].mean())/sumstd,
      'std_benzene':((avg_df['Benzene (µg/m3)'].std())/avg_df['Benzene (µg/m3)'].mean())/sumstd,
      'std_nox':((avg_df['NOX (ppb)'].std())/avg_df['NOX (ppb)'].mean())/sumstd,
      'std_so2':((avg_df['SO2 (µg/m3)'].std())/avg_df['SO2 (µg/m3)'].mean())/sumstd}

std_wt
# Out:
# {'std_pm10': 0.09275552244922487,
#  'std_no': 0.21484918202065068,
#  'std_pm2.5': 0.124598646446178,
#  'std_no2': 0.0350155544216877,
#  'std_co': 0.055066475967134626,
#  'std_nh3': 0.015255469410932856,
#  'std_ozone': 0.19146259197079157,
#  'std_benzene': 0.026019307754179773,
#  'std_nox': 0.07952707850792569,
#  'std_so2': 0.16545017105129423}

# %%
avg_df['std_wt'] = 0

for i in range(24):
    avg_df.loc[i, 'std_wt'] = ((avg_df['PM10 (µg/m3)'][i]*0.09275552244922487)+(avg_df['NO (µg/m3)'][i]*0.21484918202065068)+(avg_df['PM2.5 (µg/m3)'][x]*0.124598646446178) +
                          (avg_df['NO2 (µg/m3)'][i]*0.0350155544216877) + (avg_df['CO (mg/m3)'][i]*0.055066475967134626) + (avg_df['NH3 (µg/m3)'][i]*0.015255469410932856) + 
                          (avg_df['Ozone (µg/m3)'][i]*0.19146259197079157) + (avg_df['Benzene (µg/m3)'][i]*0.026019307754179773) + (avg_df['NOX (ppb)'][i]*0.07952707850792569) + 
                          (avg_df['SO2 (µg/m3)'][i]*0.16545017105129423))
avg_df
# Out:
#     PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  CO (mg/m3)  \
# 0     189.045541   16.712222      89.902138    60.293645    1.610151
# 1     176.841195   20.343439      90.617822    60.457005    1.581710
# 2     186.968637   23.067598      90.430967    60.152746    1.590998
# 3     187.306922   25.418070      88.042476    59.155397    1.556799
# 4     186.475603   26.745420      84.308632    58.113282    1.553550
# 5     166.538729   29.031476      85.295676    57.069076    1.600913
# 6     175.669240   34.790763     104.304872    57.233710    1.732705
# 7     198.618975   31.938035     134.891060    59.844168    1.734805
# 8     235.195090   17.001564     127.812386    62.566555    1.474171
# 9     229.073244    9.462200      87.195764    57.726483    1.264009
# 10    179.163068    6.497761      58.762349    53.958323    1.554273
# 11    135.429047    6.770200      45.180147    55.284793    1.103274
# 12    121.502252    6.703186      39.279894    49.268065    1.064034
# 13    106.995554    6.124465      36.622789    49.398101    1.075847
# 14     97.528214    5.449531      34.133945    47.570885    1.049644
# 15     86.898116    4.762088      33.797647    46.679286    1.023166
# 16     90.273464    4.275165      34.569505    45.830398    1.035183
# 17     96.608683    3.990860      40.174203    45.136377    1.074389
# 18    116.949359    4.379628      52.503478    48.964732    1.276289
# 19    141.981636    7.102860      84.418215    58.632207    1.470831
# 20    210.071470   10.776854      97.447226    64.321380    1.467269
# 21    243.012763   12.231570      81.998895    64.780411    1.510444
# 22    219.247835   13.306923      82.638342    62.871178    1.585989
# 23    185.980277   15.589251      86.706598    61.772278    1.438132
#
#     NH3 (µg/m3)  Ozone (µg/m3)  Benzene (µg/m3)  NOX (ppb)  SO2 (µg/m3)  \
# 0     13.199421      17.141340         0.190115  47.968869    20.534231
# 1     13.085201      14.553674         0.192337  50.938916    19.449314
# 2     13.323399      13.203816         0.192615  52.562523    20.080137
# 3     13.446109      13.444434         0.191934  54.125592    20.029530
# 4     13.409719      12.477164         0.187920  54.101596    20.948278
# 5     13.394897      10.371896         0.187365  55.129559    21.181442
# 6     13.530191       9.284775         0.185976  59.452637    21.587821
# 7     14.137853      14.484831         0.194309  58.697814    24.563769
# 8     14.082588      32.234517         0.197365  48.821065    25.962542
# 9     14.271769      50.181518         0.192087  39.632892    34.306715
# 10    14.069334      57.513034         0.182150  34.779563    52.739391
# 11    12.868343      59.731530         0.170115  33.745034    77.534190
# 12    14.110195      62.106964         0.163170  31.764760    73.269806
# 13    12.677290      63.700656         0.158754  31.347159    64.273261
# 14    12.688723      66.878795         0.156872  29.816261    49.808964
# 15    12.535659      66.871529         0.157393  28.793977    46.216803
# 16    12.261174      64.564132         0.157268  27.988947    40.190466
# 17    12.006576      58.865285         0.155545  27.439847    30.599009
# 18    12.429068      42.051652         0.157462  30.011494    26.681933
# 19    12.605800      31.083354         0.168295  37.764602    26.463106
# 20    12.872990      27.881838         0.175517  44.106436    25.096211
# 21    12.946807      26.015876         0.177893  46.268355    25.141412
# 22    12.874520      23.593569         0.182615  46.466054    23.306523
# 23    13.024248      20.140168         0.185052  47.247748    19.494481
#
#        std_wt
# 0   44.829482
# 1   44.041353
# 2   45.534555
# 3   46.197980
# 4   46.333625
# 5   44.658579
# 6   46.960807
# 7   50.005583
# 8   53.113700
# 9   54.833753
# 10  53.515523
# 11  53.965251
# 12  52.056769
# 13  49.353526
# 14  46.358697
# 15  44.512986
# 16  43.185340
# 17  40.964120
# 18  39.423275
# 19  41.162802
# 20  48.136366
# 21  51.346183
# 22  48.557580
# 23  44.688179

# %%
plt.figure(figsize=(20, 10))

plt.plot(avg_df['std_wt'],label = 'Pollution')

plt.xlabel("Time in 24hrs")
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# So, here we have obtained a single time series determining the pollution levels in a day at different hours.
#
# We can see that the pollution levels peak at around 0900-1000 hrs while they hit the bottom at around 1700 hrs.
#
# They again hit a peak at around 2100 hrs.
#
# There is no significant trend around the timestamp 1345 hrs to 1445 hrs, but the pollution levels seem to be decreasing during this time.
#
# It is also not fair to say that we will obsereve a sudden spike or depression around the time of blasting as it will take some time for the event to be recognised by the sensors.

# %%
df
# Out:
#                      PM10 (µg/m3)  NO (µg/m3)  PM2.5 (µg/m3)  NO2 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00        101.75   15.179643          34.75       88.675
# 2023-02-01 01:00:00        114.00   16.546883          34.25       89.500
# 2023-02-01 02:00:00         85.50   21.454525          34.25       88.875
# 2023-02-01 03:00:00         72.00   19.379084          35.00       86.775
# 2023-02-01 04:00:00         68.50   21.404340          40.00       83.025
# ...                           ...         ...            ...          ...
# 2023-05-01 19:00:00         67.50   11.375000          12.75       97.775
# 2023-05-01 20:00:00         46.25   11.775000           6.50       96.600
# 2023-05-01 21:00:00         31.00   12.075000           7.75       98.075
# 2023-05-01 22:00:00         25.75   15.625000           8.00       98.850
# 2023-05-01 23:00:00         22.25   20.025000           9.75       99.800
#
#                      NOX (ppb)  CO (mg/m3)  SO2 (µg/m3)  NH3 (µg/m3)  \
# DateTime
# 2023-02-01 00:00:00     55.550    0.350000    11.374938       19.250
# 2023-02-01 01:00:00     55.575    0.360000     8.199097       22.900
# 2023-02-01 02:00:00     55.425    0.385000     8.656719       22.775
# 2023-02-01 03:00:00     54.900    0.432500     8.396549       22.775
# 2023-02-01 04:00:00     52.625    0.397500    13.372907       20.850
# ...                        ...         ...          ...          ...
# 2023-05-01 19:00:00     61.250    0.680000    20.800000        8.700
# 2023-05-01 20:00:00     60.950    0.602500     6.750000        9.975
# 2023-05-01 21:00:00     62.000    0.622500    10.125000       10.525
# 2023-05-01 22:00:00     65.300    0.690000     9.925000       10.800
# 2023-05-01 23:00:00     69.350    0.653295    10.613728       10.675
#
#                      Ozone (µg/m3)  Benzene (µg/m3) time_period
# DateTime
# 2023-02-01 00:00:00         25.500              0.4       00:00
# 2023-02-01 01:00:00         18.950              0.4       01:00
# 2023-02-01 02:00:00         19.500              0.4       02:00
# 2023-02-01 03:00:00         16.425              0.4       03:00
# 2023-02-01 04:00:00         17.225              0.4       04:00
# ...                            ...              ...         ...
# 2023-05-01 19:00:00         26.100              0.1       19:00
# 2023-05-01 20:00:00         34.100              0.1       20:00
# 2023-05-01 21:00:00         30.825              0.1       21:00
# 2023-05-01 22:00:00         20.750              0.1       22:00
# 2023-05-01 23:00:00         31.000              0.1       23:00
#
# [2160 rows x 11 columns]
